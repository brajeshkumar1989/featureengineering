# %% [markdown]
# ## **Ordinal number encoding**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import datetime

# %%
today_date=datetime.datetime.today()

# %%
today_date
# Out:
# datetime.datetime(2024, 4, 29, 12, 35, 20, 251144)

# %%
today_date-datetime.timedelta(3)
# Out:
# datetime.datetime(2024, 4, 26, 12, 35, 20, 251144)

# %%
### List Comprehension

days=[today_date-datetime.timedelta(x) for x in range(0,15)]

# %%
import pandas as pd

data=pd.DataFrame(days)
data.columns=["Day"]

data.head()
# Out:
#                          Day
# 0 2024-04-29 12:35:20.251144
# 1 2024-04-28 12:35:20.251144
# 2 2024-04-27 12:35:20.251144
# 3 2024-04-26 12:35:20.251144
# 4 2024-04-25 12:35:20.251144

# %%
data["weekday"]=data["Day"].dt.day_name()
data.head()
# Out:
#                          Day   weekday
# 0 2024-04-29 12:35:20.251144    Monday
# 1 2024-04-28 12:35:20.251144    Sunday
# 2 2024-04-27 12:35:20.251144  Saturday
# 3 2024-04-26 12:35:20.251144    Friday
# 4 2024-04-25 12:35:20.251144  Thursday

# %%
dictionary={
    'Monday':1,'Tuesday':2,'Wednesday':3,'Thursday':4,'Friday':5,'Saturday':6,'Sunday':7
}

# %%
dictionary
# Out:
# {'Monday': 1,
#  'Tuesday': 2,
#  'Wednesday': 3,
#  'Thursday': 4,
#  'Friday': 5,
#  'Saturday': 6,
#  'Sunday': 7}

# %%
data['weekday_ordinal']=data['weekday'].map(dictionary)

# %%
data
# Out:
#                           Day    weekday  weekday_ordinal
# 0  2024-04-29 12:35:20.251144     Monday                1
# 1  2024-04-28 12:35:20.251144     Sunday                7
# 2  2024-04-27 12:35:20.251144   Saturday                6
# 3  2024-04-26 12:35:20.251144     Friday                5
# 4  2024-04-25 12:35:20.251144   Thursday                4
# 5  2024-04-24 12:35:20.251144  Wednesday                3
# 6  2024-04-23 12:35:20.251144    Tuesday                2
# 7  2024-04-22 12:35:20.251144     Monday                1
# 8  2024-04-21 12:35:20.251144     Sunday                7
# 9  2024-04-20 12:35:20.251144   Saturday                6
# 10 2024-04-19 12:35:20.251144     Friday                5
# 11 2024-04-18 12:35:20.251144   Thursday                4
# 12 2024-04-17 12:35:20.251144  Wednesday                3
# 13 2024-04-16 12:35:20.251144    Tuesday                2
# 14 2024-04-15 12:35:20.251144     Monday                1

# %% [markdown]
# #### **Count or frequency encoding**

# %%
train_set=pd.read_csv('adult.data', index_col=None,header=None)

train_set.head()
# Out:
#    0                  1       2           3   4                    5   \
# 0  39          State-gov   77516   Bachelors  13        Never-married
# 1  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2  38            Private  215646     HS-grad   9             Divorced
# 3  53            Private  234721        11th   7   Married-civ-spouse
# 4  28            Private  338409   Bachelors  13   Married-civ-spouse
#
#                    6               7       8        9     10  11  12  \
# 0        Adm-clerical   Not-in-family   White     Male  2174   0  40
# 1     Exec-managerial         Husband   White     Male     0   0  13
# 2   Handlers-cleaners   Not-in-family   White     Male     0   0  40
# 3   Handlers-cleaners         Husband   Black     Male     0   0  40
# 4      Prof-specialty            Wife   Black   Female     0   0  40
#
#                13      14
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# 3   United-States   <=50K
# 4            Cuba   <=50K

# %%
len(train_set[1].unique())

columns=[1,3,5,6,7,8,9,13]

# %%
train_set=train_set[columns]

# %%
#renaming columns to some other string
train_set.columns=['Employment','Degree','Status','Designation','Family_Job','Race','Sex','Country']

# %%
train_set.head()
# Out:
#           Employment      Degree               Status         Designation  \
# 0          State-gov   Bachelors        Never-married        Adm-clerical
# 1   Self-emp-not-inc   Bachelors   Married-civ-spouse     Exec-managerial
# 2            Private     HS-grad             Divorced   Handlers-cleaners
# 3            Private        11th   Married-civ-spouse   Handlers-cleaners
# 4            Private   Bachelors   Married-civ-spouse      Prof-specialty
#
#        Family_Job    Race      Sex         Country
# 0   Not-in-family   White     Male   United-States
# 1         Husband   White     Male   United-States
# 2   Not-in-family   White     Male   United-States
# 3         Husband   Black     Male   United-States
# 4            Wife   Black   Female            Cuba

# %%
for feature in train_set.columns[:]:
  print(feature,":",len(train_set[feature].unique()),'labels')
# Out:
# Employment : 9 labels
# Degree : 16 labels
# Status : 7 labels
# Designation : 15 labels
# Family_Job : 6 labels
# Race : 5 labels
# Sex : 2 labels
# Country : 42 labels

# %%
country_map=train_set['Country'].value_counts().to_dict()

# %%
train_set['Country']=train_set['Country'].map(country_map)

train_set.head(20)
# Out:
#            Employment         Degree                  Status  \
# 0           State-gov      Bachelors           Never-married
# 1    Self-emp-not-inc      Bachelors      Married-civ-spouse
# 2             Private        HS-grad                Divorced
# 3             Private           11th      Married-civ-spouse
# 4             Private      Bachelors      Married-civ-spouse
# 5             Private        Masters      Married-civ-spouse
# 6             Private            9th   Married-spouse-absent
# 7    Self-emp-not-inc        HS-grad      Married-civ-spouse
# 8             Private        Masters           Never-married
# 9             Private      Bachelors      Married-civ-spouse
# 10            Private   Some-college      Married-civ-spouse
# 11          State-gov      Bachelors      Married-civ-spouse
# 12            Private      Bachelors           Never-married
# 13            Private     Assoc-acdm           Never-married
# 14            Private      Assoc-voc      Married-civ-spouse
# 15            Private        7th-8th      Married-civ-spouse
# 16   Self-emp-not-inc        HS-grad           Never-married
# 17            Private        HS-grad           Never-married
# 18            Private           11th      Married-civ-spouse
# 19   Self-emp-not-inc        Masters                Divorced
#
#            Designation      Family_Job                 Race      Sex  Country
# 0         Adm-clerical   Not-in-family                White     Male    29170
# 1      Exec-managerial         Husband                White     Male    29170
# 2    Handlers-cleaners   Not-in-family                White     Male    29170
# 3    Handlers-cleaners         Husband                Black     Male    29170
# 4       Prof-specialty            Wife                Black   Female       95
# 5      Exec-managerial            Wife                White   Female    29170
# 6        Other-service   Not-in-family                Black   Female       81
# 7      Exec-managerial         Husband                White     Male    29170
# 8       Prof-specialty   Not-in-family                White   Female    29170
# 9      Exec-managerial         Husband                White     Male    29170
# 10     Exec-managerial         Husband                Black     Male    29170
# 11      Prof-specialty         Husband   Asian-Pac-Islander     Male      100
# 12        Adm-clerical       Own-child                White   Female    29170
# 13               Sales   Not-in-family                Black     Male    29170
# 14        Craft-repair         Husband   Asian-Pac-Islander     Male      583
# 15    Transport-moving         Husband   Amer-Indian-Eskimo     Male      643
# 16     Farming-fishing       Own-child                White     Male    29170
# 17   Machine-op-inspct       Unmarried                White     Male    29170
# 18               Sales         Husband                White     Male    29170
# 19     Exec-managerial       Unmarried                White   Female    29170

# %% [markdown]
# #### Advantages
#
# 1. Easy to use
# 2. Not increasing feature space (not increasing dimension), which happens with other encoding (like on hot encoding)
#
# #### Disadvantages
#
# 1. It will provide same weight if the frequencies are same. (like two countries have same value).

# %% [markdown]
# #### **Target Guided Ordinal encoding**
#
# 1. Ordering the labels according to the target
# 2. Replace the labels by the joint probability of being 1 or 0

# %%
import pandas as pd

df=pd.read_csv('Titanic-Dataset.csv', usecols=['Cabin','Survived'])
df.head()
# Out:
#    Survived Cabin
# 0         0   NaN
# 1         1   C85
# 2         1   NaN
# 3         1  C123
# 4         0   NaN
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Survived'].plot(kind='hist', bins=20, title='Survived')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('Cabin').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2['Survived'].plot(kind='line', figsize=(8, 4), title='Survived')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_3['Cabin'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_3, x='Survived', y='Cabin', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df['Cabin'].fillna('Missing',inplace=True)

df['Cabin']=df['Cabin'].astype(str).str[0]

df.head()
# Out:
#    Survived Cabin
# 0         0     M
# 1         1     C
# 2         1     M
# 3         1     C
# 4         0     M

# %%
df.Cabin.unique()
# Out:
# array(['M', 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
df.groupby(['Cabin'])['Survived'].mean()
# Out:
# Cabin
# A    0.466667
# B    0.744681
# C    0.593220
# D    0.757576
# E    0.750000
# F    0.615385
# G    0.500000
# M    0.299854
# T    0.000000
# Name: Survived, dtype: float64

# %%
#after sorting values just get the index  , so later can assign some number in order
df.groupby(['Cabin'])['Survived'].mean().sort_values().index
# Out:
# Index(['T', 'M', 'A', 'G', 'C', 'F', 'B', 'E', 'D'], dtype='object', name='Cabin')

# %%
ordinal_labels=df.groupby(['Cabin'])['Survived'].mean().sort_values().index

ordinal_labels
# Out:
# Index(['T', 'M', 'A', 'G', 'C', 'F', 'B', 'E', 'D'], dtype='object', name='Cabin')

# %%
#map all ordinal_labels to some number

ordinal_labels={k:i for i,k in enumerate(ordinal_labels,0)}
ordinal_labels
# Out:
# {'T': 0, 'M': 1, 'A': 2, 'G': 3, 'C': 4, 'F': 5, 'B': 6, 'E': 7, 'D': 8}

# %%
df['Cabin_ordinal_labels']=df['Cabin'].map(ordinal_labels)

df.head()
# Out:
#    Survived Cabin  Cabin_ordinal_labels
# 0         0     M                     1
# 1         1     C                     4
# 2         1     M                     1
# 3         1     C                     4
# 4         0     M                     1

# %% [markdown]
# #### **Mean Encoding**
#
# replace categorical value with mean

# %%
mean_ordinal=df.groupby(['Cabin'])['Survived'].mean().to_dict()

# %%
df['mean_ordinal_encode']=df['Cabin'].map(mean_ordinal)
df.head()
# Out:
#    Survived Cabin  Cabin_ordinal_labels  mean_ordinal_encode
# 0         0     M                     1             0.299854
# 1         1     C                     4             0.593220
# 2         1     M                     1             0.299854
# 3         1     C                     4             0.593220
# 4         0     M                     1             0.299854
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4['Survived'].plot(kind='hist', bins=20, title='Survived')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5['Cabin_ordinal_labels'].plot(kind='hist', bins=20, title='Cabin_ordinal_labels')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6['mean_ordinal_encode'].plot(kind='hist', bins=20, title='mean_ordinal_encode')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_7.groupby('Cabin').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='Survived', y='Cabin_ordinal_labels', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9.plot(kind='scatter', x='Cabin_ordinal_labels', y='mean_ordinal_encode', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_10['Survived'].plot(kind='line', figsize=(8, 4), title='Survived')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['Cabin_ordinal_labels'].plot(kind='line', figsize=(8, 4), title='Cabin_ordinal_labels')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_12['mean_ordinal_encode'].plot(kind='line', figsize=(8, 4), title='mean_ordinal_encode')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_13['Cabin'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_13, x='Survived', y='Cabin', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_14['Cabin'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_14, x='Cabin_ordinal_labels', y='Cabin', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_15['Cabin'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_15, x='mean_ordinal_encode', y='Cabin', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# #### Advantage
# 1. Help to not increase dimension of data
# #### Disadvantage
# 1. It leads to overfitting
